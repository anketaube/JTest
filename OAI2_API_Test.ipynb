# %% [markdown]
# # DNBLab Jupyter Notebook Tutorial

# %% [markdown]
# ## Schnittstellenabfragen, Datenauslieferung und Ergebnisanzeige

# %% [markdown]
# Diese DNBLab-Tutorials beschreiben Beispielabfragen über die OAI- und SRU-Schnittstelle mit Python. In der Jupyter Notebook Umgebung kann der dokumentierte Code direkt ausgeführt und angepasst werden. Die Tutorials umfassen die exemplarische Anfrage und Ausgabe der Daten in den verschiedenen Metadatenformaten zur weiteren Verarbeitung.
#
# **Inhaltsverzeichnis:**
#
# * [1. OAI2 - Schnittstelle ](#API1)
# * [2. OAI - Schnittstelle ](#API2)
# * [3. SRU - Schnittstelle](#API3)

# %% [markdown]
# ## OAI2- Schnittstelle <a class="anchor" id="API1"></a>

# %% [markdown]
# Die Daten werden über die OAI2-Schnittstelle standardmäßig als XML-Antwort in dem Format METS/MODS ausgeliefert. Zusätzlich steht die Auslieferung der Daten in Dublin Core (DC) zur Verfügung.
#
# Inhaltsverzeichnis:
#
# * [1. Einrichten der Arbeitsumgebung](#Teil1)
# * [2. Ausgabe von Titeln eines Projekts in bestimmten Zeitraum](#Teil2)
# * [3. Zusätzliche Ausgabe der Links zu den Objekten](#Teil3)
# * [4. Ausgabe der gescannten Bilder](#Teil4)

# %% [markdown]
# ### 1. Einrichten der Arbeitsumgebung <a class="anchor" id="Teil1"></a>
#
# Um die Arbeitsumgebung für die folgenden Schritte passend einzurichten, sollten zunächst die benötigten Python-Bibliotheken importiert werden. Für Anfragen über die OAI2 Schnittstelle wird sickle https://sickle.readthedocs.io/en/latest/tutorial.html und zur Verarbeitung der XML-Daten etree https://docs.python.org/3/library/xml.etree.elementtree.html verwendet.

# %%
from sickle import Sickle
from lxml import etree

# %% [markdown]
# Die OAI2 Basis URL ist http://services.dnb.de/oai2/repository.

# %%
sickle = Sickle('http://services.dnb.de/oai2/repository')

# %% [markdown]
# Im nächsten Schritt werden alle verfügbaren Objektsammlungen (Projekte) mit der Funktion ListSets abgefragt und angezeigt.

# %%
oai_sets = sickle.ListSets()
for oai_set in oai_sets:
    print('setSpec value for selective harvesting: ' + oai_set.setSpec)
    print('Name of the set (setName): ' + oai_set.setName + '\n')
# Out:
# setSpec value for selective harvesting: dnb:digitalisate-oa
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access)
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt1
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 1
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt2
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 2
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt3
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 3
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt4
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 4
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt5
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 5
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt6
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 6
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt7
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 7
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt8
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 8
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt9
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 9
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt10
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 10
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt11
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 11
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt12
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 12
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt13
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 13
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt14
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 14
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt15
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 15
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt16
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 16
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt17
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 17
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt18
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 18
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt19
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 19
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt20
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 20
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt21
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 21
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt22
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 22
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt23
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 23
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt24
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 24
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt25
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 25
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt26
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 26
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt27
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 27
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt28
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 28
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt29
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 29
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt30
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 30
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt31
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 31
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt32
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 32
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt33
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 33
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt34
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 34
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt35
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 35
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt36
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 36
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt37
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 37
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt38
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 38
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt39
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 39
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt40
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 40
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt41
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 41
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt42
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 42
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt43
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 43
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt44
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 44
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt45
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 45
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt46
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 46
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt47
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 47
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt48
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 48
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt49
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 49
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt50
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 50
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt51
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 51
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt52
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 52
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt53
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 53
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt54
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 54
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt55
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 55
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt56
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 56
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt57
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 57
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt58
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 58
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt59
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 59
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt60
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 60
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt61
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 61
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt62
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 62
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt63
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 63
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt64
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 64
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt65
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 65
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt66
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 66
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt67
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 67
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt68
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 68
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt69
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 69
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt70
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 70
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt71
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 71
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt72
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 72
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt73
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 73
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt74
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 74
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt75
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 75
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt76
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 76
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt77
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 77
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt78
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 78
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt79
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 79
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt80
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 80
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt81
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 81
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt82
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 82
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt83
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 83
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt84
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 84
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt85
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 85
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt86
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 86
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt87
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 87
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt88
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 88
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt89
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 89
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt90
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 90
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt91
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 91
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt92
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 92
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt93
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 93
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt94
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 94
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt95
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 95
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt96
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 96
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt97
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 97
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt98
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 98
#
# setSpec value for selective harvesting: dnb:digitalisate-oa:projekt99
# Name of the set (setName): Gemeinfreie Digitalisate von Druckwerken (Open Access) - Projekt 99

# %% [markdown]
# Die bisher zur Verfügung stehenden freien Objektsammlungen entsprechen folgenden Projekten (oai_sets):
#
# | oai_set | Beschreibung | Anzeige im Katalog |
# | --- | --- | --- |
# | dnb:digitalisate-oa:projekt4 | 100.000 Seiten aus 30 Titeln, die ein breites Spektrum der Exilpresse 1933-1945 repräsentieren | <a href="https://portal.dnb.de/opac.htm?method=showPreviousResultSite&currentResultId=%22exilpresse%22+and+%22digital%22%26any%26dnb.dea.exp%26leipzig&currentPosition=10">Sammlung im Katalog</a>
# | dnb:digitalisate-oa:projekt7 | Gemeinfreie Digitalisate der Exilsammlungen | <a href="https://portal.dnb.de/opac.htm?query=cod%3Dd007+location%3Donlinefree+&method=simpleSearch&cqlMode=true">Sammlung im Katalog</a>
# | dnb:digitalisate-oa:projekt8 | 1Mehr als 1.200 Bücher, Broschüren, Plakate und andere Einblattdrucke zum Weltkrieg 1914-1918 | <a href="https://portal.dnb.de/opac.htm?query=cod%3Dd008+location%3Donlinefree+&method=simpleSearch&cqlMode=true">Sammlung im Katalog</a>
# | dnb:digitalisate-oa:projekt26 | Mehr als 600 digitalisierte Quellen zur deutschen Revolution 1918/1919 und zur Nachkriegszeit | <a href="https://portal.dnb.de/opac.htm?query=cod%3Dd026+location%3Donlinefree+&method=simpleSearch&cqlMode=true">Sammlung im Katalog</a>
# | dnb:digitalisate-oa:projekt28 | Digitalisierte Werke aus Architektur, Design, Malerei und Druckkunst von 1918 bis 1933 | <a href="https://portal.dnb.de/opac.htm?query=cod%3Dd028+location%3Donlinefree+&method=simpleSearch&cqlMode=true">Sammlung im Katalog</a>
# | dnb:digitalisate-oa:projekt29 | Mehr als 2.400 Bildnisse von Buchhändlern, Buchdruckern und Verlegern des 17. bis 20. Jahrhunderts | <a href="https://portal.dnb.de/opac.htm?query=cod%3Dd029+location%3Donlinefree+&method=simpleSearch&cqlMode=true">Sammlung im Katalog</a>
#
# Die verfügbaren Metadatenformate können mit der Funktion ListMetadataFormats abgefragt und mit print() ausgegeben werden.

# %%
oai_formats = sickle.ListMetadataFormats()
for oai_format in oai_formats:
    print(oai_format.metadataPrefix)
# Out:
# mets
# oai_dc

# %% [markdown]
# ### 2. Ausgabe von Titeln eines Projekts in bestimmten Zeitraum <a class="anchor" id="Teil2"></a>

# %% [markdown]
# Um beispielhaft alle Datensätze der Buchhändlerportraits (Projekt29) ab dem 01.04.2019 aufzulisten, müssen für die Abfrage Metadatenformat, Zeitraum und Projekt angegeben werden.
# Die OAI Funktionen werden unter http://www.openarchives.org/OAI/2.0/ spezifiziert und auf der DNBLab Seite unter Funktionen beschrieben.
# Die Daten befinden sich in der XML-Antwort als Inhalt zwischen beschreibenden <Tags>. Für die gezielte Abfrage der gewünschten Informationen aus dem Metadatenformat DC, können bei Bedarf die DC-Spezifikationen http://www.openarchives.org/OAI/2.0/oai_dc/ und http://purl.org/dc/elements/1.1/ herangezogen werden.

# %%
namespaces = {
    'oai': 'http://www.openarchives.org/OAI/2.0/',
    'oai_dc': 'http://www.openarchives.org/OAI/2.0/oai_dc/',
    'dc': 'http://purl.org/dc/elements/1.1/'
}

count=0

for record in sickle.ListRecords(**{'metadataPrefix': 'oai_dc', 'from': '2019-04-30', 'set': 'dnb:digitalisate-oa:projekt29'}):
    
    if ('ger' in record.raw):
        #print('-' + record.raw + '-')
        tree = etree.ElementTree(record.xml)
        result = tree.xpath('/oai:record/oai:metadata/oai_dc:dc/dc:title/text()', namespaces=namespaces)
        if (result):
            count += 1
            author = tree.xpath('/oai:record/oai:metadata/oai_dc:dc/dc:title/text()', namespaces=namespaces)
            print(str(count) + ": " + result[0])
            if author:
                print(author[0])

# %% [markdown]
# ### 3. Zusätzliche Ausgabe der Links zu den Objekten <a class="anchor" id="Teil3"></a>

# %% [markdown]
# Damit zusätzlich zu den Titeln die Links zu den Objekten ausgegeben werden, wird der URN entsprechend des dc-Schemas /oai:record/oai:metadata/oai_dc:dc/dc:identifier/text() angesprochen und zusammen mit dem Titel durchnummeriert angezeigt.

# %%
namespaces = {
    'oai': 'http://www.openarchives.org/OAI/2.0/',
    'oai_dc': 'http://www.openarchives.org/OAI/2.0/oai_dc/',
    'dc': 'http://purl.org/dc/elements/1.1/'
}

count=0

for record in sickle.ListRecords(**{'metadataPrefix': 'oai_dc', 'from': '2019-04-30', 'set': 'dnb:digitalisate-oa:projekt29'}):
    
    if ('ger' in record.raw):
        #print('-' + record.raw + '-')
        tree = etree.ElementTree(record.xml)
        result = tree.xpath('/oai:record/oai:metadata/oai_dc:dc/dc:title/text()', namespaces=namespaces)
        if (result):
            count += 1
            author = tree.xpath('/oai:record/oai:metadata/oai_dc:dc/dc:identifier/text()', namespaces=namespaces)
            print(str(count) + ": " + result[0])
            if author:
                print(author[0])
# Out:
# 1: Porträt Adolf Holzhausen ? : Radierung / Beschriftet u.l.: Probedruck W. Unger
# urn:nbn:de:101:1-2018100109111525182971
# 2: Porträt Wilhelm Volkmann (1837 - 1896) : Heliogravüre / Bez. u.l.: Phot. Aufnahme von Georg Brokesch, Leipzig; u.r.: Photogravure R. Paulussen, Wien
# urn:nbn:de:101:1-2018100109003388755688
# 3: Porträt Johann Baptist Strobel (1748 - 1805) und seine Kinder : Heliogravüre / Bez. u.r.: F. BRUCKMANN A. G. MÜNCHEN
# urn:nbn:de:101:1-2018100108430368319151
# 4: Porträt Ernst A. Seemann (1829 - 1904) : Heliogravüre / Bez. u.M.: Photogravure R. Paulussen, Wien
# urn:nbn:de:101:1-2018100108494012771701
# 5: Porträt Johann Leonhard Schrag (1783 - 1858) : Heliogravüre / Bez. u.l.: M.? Wolfsheimer pinx.; u.r.: Photogravure Bruckmann
# urn:nbn:de:101:1-2018100108480441933541
# 6: Porträt Christian Friedrich Adolf Rost (1790 - 1856) : Lithographie / Bez. um Oval u.l.: A. Schieferdecker lith. / Leipzig 1857.; im Oval u.r.: Druck d. Kön. lith. Inst. zu Berlin; darunter u.l.: Gem. v. A. Brasch.
# 20: Porträt Alexander Edelmann : Stahlstich / Bez. u.l.: Nach einer Photographie; u.r.: Stich u. Druck v. A u. Th. Weger, Leipzig
# urn:nbn:de:101:1-2018092708154013917973
# 21: Porträt Franz Deuticke : Heliogravüre / Bez. u.M.: Photogravure von R. Paulussen, Wien.
# urn:nbn:de:101:1-2018092708123231501754
# 22: Porträt Joseph Vinzenz Degen : Punktiermanier / Bez. u. M.: Agricola pinx: 1804. F: John sc
# urn:nbn:de:101:1-2018092708121437953845
# 23: Porträt John Boydell : Punktiermanier mit Ätzung / Bez. u.l.: C. Borckhardt del.; u.r.: B. Smith sculpsit; Verlegeradresse unter der Schrift: Pub Jan 10 1906 by Boydell & C° Cheapside London
# urn:nbn:de:101:1-2018092707260722904659
# 24: Porträt John Boydell (1719 - 1804) : Punktiermanier mit Ätzung / Bez. u.l.: Painted by G. Stuart; u.r.: Engraved by Facius; Verlegeradresse unter der Schrift: Pub'd June 4. 1802. by J. et J. Boydell N°. 90. Cheapside et at the Shakespeare Gallery Pall Mall, London.
# urn:nbn:de:101:1-2018092707571759175415
# 25: Porträt Martin Bossange : Holzstich / unbez.
# urn:nbn:de:101:1-2018092707255721146616
# 26: Porträt Franz Kroh (Pseudonym Hans Blumenthal) : Heliogravüre / Bez. u.M.: PHOTOGRAVURE R. PAULUSSEN, Wien
# urn:nbn:de:101:1-2018092707551425199092

# %% [markdown]
# ### 4. Ausgabe der gescannten Bilder <a class="anchor" id="Teil4"></a>

# %% [markdown]
# Das Format METS bildet neben den bibliographischen Daten im Format mods die Struktur der digitalen Objekte bzw. die Reihenfolge der gescannten Bilder ab. Für die gezielte Abfrage der gewünschten Informationen aus dem Metadatenformat METS können bei Bedarf die METS-Spezifikationen http://www.loc.gov/METS/ und https://www.loc.gov/standards/mets/mets.xsd herangezogen werden. Die Links der einzelnen Bilder können über <xsd:element name="fileGrp"> angesprochen und zur weiteren Verarbeitung ausgegeben werden.

# %%
Count=0

for record in sickle.ListRecords(**{'metadataPrefix': 'mets', 'from': '2019-04-01', 'set': 'dnb:digitalisate-oa:projekt29'}):    
    print(record)
# Out:
# <record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>oai:dnb.de/dnb:digitalisate-oa:projekt29/1163107948</identifier><datestamp>2020-09-04T22:07:13Z</datestamp><setSpec>dnb:digitalisate-oa:projekt29</setSpec></header><metadata><METS:mets xmlns:dv="http://dfg-viewer.de/" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:METS="http://www.loc.gov/METS/" xmlns:xlink="http://www.w3.org/1999/xlink" LABEL="Digitalisat der Deutschen Nationalbibliothek" OBJID="1163107948" TYPE="BOOK" xsi:schemaLocation="http://www.loc.gov/METS http://www.loc.gov/standards/mets/mets.xsd"><METS:metsHdr CREATEDATE="2021-03-07T11:16:19.160+01:00"><METS:agent ROLE="CREATOR" TYPE="ORGANIZATION"><METS:name>Deutsche Nationalbibliothek</METS:name></METS:agent></METS:metsHdr><METS:dmdSec ID="dmd_1163107948"><METS:mdWrap MDTYPE="MODS" MIMETYPE="text/xml"><METS:xmlData><mods:mods><mods:recordInfo><mods:recordIdentifier source="dnb">1163107948</mods:recordIdentifier></mods:recordInfo><mods:identifier type="uri">http://d-nb.info/1163107948</mods:identifier><mods:identifier type="urn">urn:nbn:de:101:1-2018100109111525182971</mods:identifier><mods:location><mods:physicalLocation>Deutsche Nationalbibliothek Leipzig, Frankfurt am Main</mods:physicalLocation><mods:url access="raw object">http://nbn-resolving.org/urn:nbn:de:101:1-2018100109111525182971</mods:url></mods:location><mods:language><mods:languageTerm authority="iso639-2b" type="code">ger</mods:languageTerm></mods:language><mods:originInfo eventType="digitization"><mods:place><mods:placeTerm type="text">Leipzig</mods:placeTerm></mods:place><mods:place><mods:placeTerm type="text">Frankfurt am Main</mods:placeTerm></mods:place><mods:publisher>Deutsche Nationalbibliothek</mods:publisher><mods:dateIssued encoding="iso8601" keyDate="yes">2018</mods:dateIssued></mods:originInfo><mods:physicalDescription><mods:extent>Beschriftet u.l.: Probedruck W. Unger</mods:extent><mods:extent>1 Ex.</mods:extent><mods:digitalOrigin>reformatted digital</mods:digitalOrigin></mods:physicalDescription><mods:titleInfo><mods:title>Porträt Adolf Holzhausen ?</mods:title><mods:subTitle>Radierung</mods:subTitle></mods:titleInfo></mods:mods></METS:xmlData></METS:mdWrap></METS:dmdSec><METS:amdSec ID="amd_1163107948"><METS:rightsMD ID="rights_1163107948"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVRIGHTS"><METS:xmlData><dv:rights><dv:owner>Deutsche Nationalbibliothek</dv:owner><dv:ownerContact>mailto:digitalisierung@dnb.de</dv:ownerContact><dv:ownerlogo>https://www.dnb.de/logo-dnb-dfg-viewer</dv:ownerlogo><dv:ownerSiteURL>https://www.dnb.de/</dv:ownerSiteURL><dv:license>http://rightsstatements.org/vocab/InC/1.0/</dv:license></dv:rights></METS:xmlData></METS:mdWrap></METS:rightsMD><METS:digiprovMD ID="digiprov_1163107948"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVLINKS"><METS:xmlData><dv:links><dv:reference>https://d-nb.info/1163107948</dv:reference><dv:presentation>https://nbn-resolving.org/urn:nbn:de:101:1-2018100109111525182971</dv:presentation></dv:links></METS:xmlData></METS:mdWrap></METS:digiprovMD></METS:amdSec><METS:fileSec><METS:fileGrp USE="THUMBS"><METS:file ID="THUMBS_1163107948_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163107948/img/page/1/p.jpg?reduce=55.4"/></METS:file></METS:fileGrp><METS:fileGrp USE="DEFAULT"><METS:file ID="DEFAULT_1163107948_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163107948/img/page/1/p.jpg?reduce=5.9"/></METS:file></METS:fileGrp></METS:fileSec><METS:structMap TYPE="PHYSICAL"><METS:div ID="physMD_1163107948" TYPE="physSequence"><METS:div ID="physMD_1163107948_1" LABEL="1" ORDER="1" ORDERLABEL="1" TYPE="page"><METS:fptr FILEID="THUMBS_1163107948_1"/><METS:fptr FILEID="DEFAULT_1163107948_1"/></METS:div></METS:div></METS:structMap><METS:structMap TYPE="LOGICAL"><METS:div ADMID="amd_1163107948" DMDID="dmd_1163107948" ID="logMD_ ...
# <record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>oai:dnb.de/dnb:digitalisate-oa:projekt29/1163105767</identifier><datestamp>2020-06-03T21:57:49Z</datestamp><setSpec>dnb:digitalisate-oa:projekt29</setSpec></header><metadata><METS:mets xmlns:dv="http://dfg-viewer.de/" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:METS="http://www.loc.gov/METS/" xmlns:xlink="http://www.w3.org/1999/xlink" LABEL="Digitalisat der Deutschen Nationalbibliothek" OBJID="1163105767" TYPE="BOOK" xsi:schemaLocation="http://www.loc.gov/METS http://www.loc.gov/standards/mets/mets.xsd"><METS:metsHdr CREATEDATE="2021-03-07T11:16:19.437+01:00"><METS:agent ROLE="CREATOR" TYPE="ORGANIZATION"><METS:name>Deutsche Nationalbibliothek</METS:name></METS:agent></METS:metsHdr><METS:dmdSec ID="dmd_1163105767"><METS:mdWrap MDTYPE="MODS" MIMETYPE="text/xml"><METS:xmlData><mods:mods><mods:recordInfo><mods:recordIdentifier source="dnb">1163105767</mods:recordIdentifier></mods:recordInfo><mods:identifier type="uri">http://d-nb.info/1163105767</mods:identifier><mods:identifier type="urn">urn:nbn:de:101:1-2018100109003388755688</mods:identifier><mods:location><mods:physicalLocation>Deutsche Nationalbibliothek Leipzig, Frankfurt am Main</mods:physicalLocation><mods:url access="raw object">http://nbn-resolving.org/urn:nbn:de:101:1-2018100109003388755688</mods:url></mods:location><mods:language><mods:languageTerm authority="iso639-2b" type="code">ger</mods:languageTerm></mods:language><mods:originInfo eventType="digitization"><mods:place><mods:placeTerm type="text">Leipzig</mods:placeTerm></mods:place><mods:place><mods:placeTerm type="text">Frankfurt am Main</mods:placeTerm></mods:place><mods:publisher>Deutsche Nationalbibliothek</mods:publisher><mods:dateIssued encoding="iso8601" keyDate="yes">2018</mods:dateIssued></mods:originInfo><mods:physicalDescription><mods:extent>Bez. u.l.: Phot. Aufnahme von Georg Brokesch, Leipzig; u.r.: Photogravure R. Paulussen, Wien</mods:extent><mods:extent>2 Ex.</mods:extent><mods:digitalOrigin>reformatted digital</mods:digitalOrigin></mods:physicalDescription><mods:titleInfo><mods:title>Porträt Wilhelm Volkmann (1837 - 1896)</mods:title><mods:subTitle>Heliogravüre</mods:subTitle></mods:titleInfo></mods:mods></METS:xmlData></METS:mdWrap></METS:dmdSec><METS:amdSec ID="amd_1
mods:url></mods:location><mods:language><mods:languageTerm authority="iso639-2b" type="code">ger</mods:languageTerm></mods:language><mods:originInfo eventType="digitization"><mods:place><mods:placeTerm type="text">Leipzig</mods:placeTerm></mods:place><mods:place><mods:placeTerm type="text">Frankfurt am Main</mods:placeTerm></mods:place><mods:publisher>Deutsche Nationalbibliothek</mods:publisher><mods:dateIssued encoding="iso8601" keyDate="yes">2018</mods:dateIssued></mods:originInfo><mods:physicalDescription><mods:extent>Bez. u.M.: Photogravure von R. Paulussen, Wien.</mods:extent><mods:extent>2 Ex.</mods:extent><mods:digitalOrigin>reformatted digital</mods:digitalOrigin></mods:physicalDescription><mods:titleInfo><mods:title>Porträt Eugen Marx (1844 - 1934)</mods:title><mods:subTitle>Heliogravüre</mods:subTitle></mods:titleInfo></mods:mods></METS:xmlData></METS:mdWrap></METS:dmdSec><METS:amdSec ID="amd_1163087769"><METS:rightsMD ID="rights_1163087769"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVRIGHTS"><METS:xmlData><dv:rights><dv:owner>Deutsche Nationalbibliothek</dv:owner><dv:ownerContact>mailto:digitalisierung@dnb.de</dv:ownerContact><dv:ownerlogo>https://www.dnb.de/logo-dnb-dfg-viewer</dv:ownerlogo><dv:ownerSiteURL>https://www.dnb.de/</dv:ownerSiteURL><dv:license>http://rightsstatements.org/vocab/InC/1.0/</dv:license></dv:rights></METS:xmlData></METS:mdWrap></METS:rightsMD><METS:digiprovMD ID="digiprov_1163087769"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVLINKS"><METS:xmlData><dv:links><dv:reference>https://d-nb.info/1163087769</dv:reference><dv:presentation>https://nbn-resolving.org/urn:nbn:de:101:1-2018100108265322361355</dv:presentation></dv:links></METS:xmlData></METS:mdWrap></METS:digiprovMD></METS:amdSec><METS:fileSec><METS:fileGrp USE="THUMBS"><METS:file ID="THUMBS_1163087769_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163087769/img/page/1/p.jpg?reduce=52.2"/></METS:file></METS:fileGrp><METS:fileGrp USE="DEFAULT"><METS:file ID="DEFAULT_1163087769_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163087769/img/page/1/p.jpg?reduce=5.6"/></METS:file></METS:fileGrp></METS:fileSec><METS:structMap TYPE="PHYSICAL"><METS:div ID="physMD_1163087769" TYPE="physSequence"><METS:div ID="physMD_1163087769_1" LABEL="1" ORDER="1" ORDERLABEL="1" TYPE="page"><METS:fptr FILEID="THUMBS_1163087769_1"/><METS:fptr FILEID="DEFAULT_1163087769_1"/></METS:div></METS:div></METS:structMap><METS:structMap TYPE="LOGICAL"><METS:div ADMID="amd_1163087769" DMDID="dmd_11 ...
# ...
# <record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>oai:dnb.de/dnb:digitalisate-oa:projekt29/1163023965</identifier><datestamp>2020-04-22T00:30:32Z</datestamp><setSpec>dnb:digitalisate-oa:projekt29</setSpec></header><metadata><METS:mets xmlns:dv="http://dfg-viewer.de/" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:METS="http://www.loc.gov/METS/" xmlns:xlink="http://www.w3.org/1999/xlink" LABEL="Digitalisat der Deutschen Nationalbibliothek" OBJID="1163023965" TYPE="BOOK" xsi:schemaLocation="http://www.loc.gov/METS http://www.loc.gov/standards/mets/mets.xsd"><METS:metsHdr CREATEDATE="2021-03-07T11:16:21.887+01:00"><METS:agent ROLE="CREATOR" TYPE="ORGANIZATION"><METS:name>Deutsche Nationalbibliothek</METS:name></METS:agent></METS:metsHdr><METS:dmdSec ID="dmd_1163023965"><METS:mdWrap MDTYPE="MODS" MIMETYPE="text/xml"><METS:xmlData><mods:mods><mods:recordInfo><mods:recordIdentifier source="dnb">1163023965</mods:recordIdentifier></mods:recordInfo><mods:identifier type="uri">http://d-nb.info/1163023965</mods:identifier><mods:identifier type="urn">urn:nbn:de:101:1-2018092707571759175415</mods:identifier><mods:location><mods:physicalLocation>Deutsche Nationalbibliothek Leipzig, Frankfurt am Main</mods:physicalLocation><mods:url access="raw object">http://nbn-resolving.org/urn:nbn:de:101:1-2018092707571759175415</mods:url></mods:location><mods:language><mods:languageTerm authority="iso639-2b" type="code">ger</mods:languageTerm></mods:language><mods:originInfo eventType="digitization"><mods:place><mods:placeTerm type="text">Leipzig</mods:placeTerm></mods:place><mods:place><mods:placeTerm type="text">Frankfurt am Main</mods:placeTerm></mods:place><mods:publisher>Deutsche Nationalbibliothek</mods:publisher><mods:dateIssued encoding="iso8601" keyDate="yes">2018</mods:dateIssued></mods:originInfo><mods:physicalDescription><mods:extent>Bez. u.l.: Painted by G. Stuart; u.r.: Engraved by Facius; Verlegeradresse unter der Schrift: Pub'd June 4. 1802. by J. et J. Boydell N°. 90. Cheapside et at the Shakespeare Gallery Pall Mall, London.</mods:extent><mods:extent>2 Ex.</mods:extent><mods:digitalOrigin>reformatted digital</mods:digitalOrigin></mods:physicalDescription><mods:titleInfo><mods:title>Porträt John Boydell (1719 - 1804)</mods:title><mods:subTitle>Punktiermanier mit Ätzung</mods:subTitle></mods:titleInfo></mods:mods></METS:xmlData></METS:mdWrap></METS:dmdSec><METS:amdSec ID="amd_1163023965"><METS:rightsMD ID="rights_1163023965"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVRIGHTS"><METS:xmlData><dv:rights><dv:owner>Deutsche Nationalbibliothek</dv:owner><dv:ownerContact>mailto:digitalisierung@dnb.de</dv:ownerContact><dv:ownerlogo>https://www.dnb.de/logo-dnb-dfg-viewer</dv:ownerlogo><dv:ownerSiteURL>https://www.dnb.de/</dv:ownerSiteURL><dv:license>http://rightsstatements.org/vocab/InC/1.0/</dv:license></dv:rights></METS:xmlData></METS:mdWrap></METS:rightsMD><METS:digiprovMD ID="digiprov_1163023965"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVLINKS"><METS:xmlData><dv:links><dv:reference>https://d-nb.info/1163023965</dv:reference><dv:presentation>https://nbn-resolving.org/urn:nbn:de:101:1-2018092707571759175415</dv:presentation></dv:links></METS:xmlData></METS:mdWrap></METS:digiprovMD></METS:amdSec><METS:fileSec><METS:fileGrp USE="THUMBS"><METS:file ID="THUMBS_1163023965_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163023965/img/page/1/p.jpg?reduce=61"/></METS:file></METS:fileGrp><METS:fileGrp USE="DEFAULT"><METS:file ID="DEFAULT_1163023965_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163023965/img/page/1/p.jpg?reduce=6.5"/></METS:file></METS:fileGrp></METS:fileSec><METS:structMap TYPE="PHYSICAL"><METS:div ID="physMD_1163023965" TYPE="physSequence"><METS:div ID="physMD_1163023965_1" LABEL="1" ORDER="1" ORDERLABEL="1" TYPE="page"><METS:fptr FILEID="THUMBS_1163023 ...
# <record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>oai:dnb.de/dnb:digitalisate-oa:projekt29/116302371X</identifier><datestamp>2021-02-05T18:13:47Z</datestamp><setSpec>dnb:digitalisate-oa:projekt29</setSpec></header><metadata><METS:mets xmlns:dv="http://dfg-viewer.de/" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:METS="http://www.loc.gov/METS/" xmlns:xlink="http://www.w3.org/1999/xlink" LABEL="Digitalisat der Deutschen Nationalbibliothek" OBJID="116302371X" TYPE="BOOK" xsi:schemaLocation="http://www.loc.gov/METS http://www.loc.gov/standards/mets/mets.xsd"><METS:metsHdr CREATEDATE="2021-03-07T11:16:22.023+01:00"><METS:agent ROLE="CREATOR" TYPE="ORGANIZATION"><METS:name>Deutsche Nationalbibliothek</METS:name></METS:agent></METS:metsHdr><METS:dmdSec ID="dmd_116302371X"><METS:mdWrap MDTYPE="MODS" MIMETYPE="text/xml"><METS:xmlData><mods:mods><mods:recordInfo><mods:recordIdentifier source="dnb">116302371X</mods:recordIdentifier></mods:recordInfo><mods:identifier type="uri">http://d-nb.info/116302371X</mods:identifier><mods:identifier type="urn">urn:nbn:de:101:1-2018092707255721146616</mods:identifier><mods:location><mods:physicalLocation>Deutsche Nationalbibliothek Leipzig, Frankfurt am Main</mods:physicalLocation><mods:url access="raw object">http://nbn-resolving.org/urn:nbn:de:101:1-2018092707255721146616</mods:url></mods:location><mods:language><mods:languageTerm authority="iso639-2b" type="code">ger</mods:languageTerm></mods:language><mods:originInfo eventType="digitization"><mods:place><mods:placeTerm type="text">Leipzig</mods:placeTerm></mods:place><mods:place><mods:placeTerm type="text">Frankfurt am Main</mods:placeTerm></mods:place><mods:publisher>Deutsche Nationalbibliothek</mods:publisher><mods:dateIssued encoding="iso8601" keyDate="yes">2018</mods:dateIssued></mods:originInfo><mods:physicalDescription><mods:extent>unbez.</mods:extent><mods:extent>1 Ex.</mods:extent><mods:digitalOrigin>reformatted digital</mods:digitalOrigin></mods:physicalDescription><mods:titleInfo><mods:title>Porträt Martin Bossange</mods:title><mods:subTitle>Holzstich</mods:subTitle></mods:titleInfo></mods:mods></METS:xmlData></METS:mdWrap></METS:dmdSec><METS:amdSec ID="amd_116302371X"><METS:rightsMD ID="rights_116302371X"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVRIGHTS"><METS:xmlData><dv:rights><dv:owner>Deutsche Nationalbibliothek</dv:owner><dv:ownerContact>mailto:digitalisierung@dnb.de</dv:ownerContact><dv:ownerlogo>https://www.dnb.de/logo-dnb-dfg-viewer</dv:ownerlogo><dv:ownerSiteURL>https://www.dnb.de/</dv:ownerSiteURL><dv:license>http://rightsstatements.org/vocab/InC/1.0/</dv:license></dv:rights></METS:xmlData></METS:mdWrap></METS:rightsMD><METS:digiprovMD ID="digiprov_116302371X"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVLINKS"><METS:xmlData><dv:links><dv:reference>https://d-nb.info/116302371X</dv:reference><dv:presentation>https://nbn-resolving.org/urn:nbn:de:101:1-2018092707255721146616</dv:presentation></dv:links></METS:xmlData></METS:mdWrap></METS:digiprovMD></METS:amdSec><METS:fileSec><METS:fileGrp USE="THUMBS"><METS:file ID="THUMBS_116302371X_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/116302371X/img/page/1/p.jpg?reduce=33.7"/></METS:file></METS:fileGrp><METS:fileGrp USE="DEFAULT"><METS:file ID="DEFAULT_116302371X_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/116302371X/img/page/1/p.jpg?reduce=3.6"/></METS:file></METS:fileGrp></METS:fileSec><METS:structMap TYPE="PHYSICAL"><METS:div ID="physMD_116302371X" TYPE="physSequence"><METS:div ID="physMD_116302371X_1" LABEL="1" ORDER="1" ORDERLABEL="1" TYPE="page"><METS:fptr FILEID="THUMBS_116302371X_1"/><METS:fptr FILEID="DEFAULT_116302371X_1"/></METS:div></METS:div></METS:structMap><METS:structMap TYPE="LOGICAL"><METS:div ADMID="amd_116302371X" DMDID="dmd_116302371X" ID="logMD_116302371X"/></METS:structMap><MET ...
# <record xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"><header><identifier>oai:dnb.de/dnb:digitalisate-oa:projekt29/1163022497</identifier><datestamp>2020-06-03T22:09:43Z</datestamp><setSpec>dnb:digitalisate-oa:projekt29</setSpec></header><metadata><METS:mets xmlns:dv="http://dfg-viewer.de/" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:METS="http://www.loc.gov/METS/" xmlns:xlink="http://www.w3.org/1999/xlink" LABEL="Digitalisat der Deutschen Nationalbibliothek" OBJID="1163022497" TYPE="BOOK" xsi:schemaLocation="http://www.loc.gov/METS http://www.loc.gov/standards/mets/mets.xsd"><METS:metsHdr CREATEDATE="2021-03-07T11:16:22.125+01:00"><METS:agent ROLE="CREATOR" TYPE="ORGANIZATION"><METS:name>Deutsche Nationalbibliothek</METS:name></METS:agent></METS:metsHdr><METS:dmdSec ID="dmd_1163022497"><METS:mdWrap MDTYPE="MODS" MIMETYPE="text/xml"><METS:xmlData><mods:mods><mods:recordInfo><mods:recordIdentifier source="dnb">1163022497</mods:recordIdentifier></mods:recordInfo><mods:identifier type="uri">http://d-nb.info/1163022497</mods:identifier><mods:identifier type="urn">urn:nbn:de:101:1-2018092707551425199092</mods:identifier><mods:location><mods:physicalLocation>Deutsche Nationalbibliothek Leipzig, Frankfurt am Main</mods:physicalLocation><mods:url access="raw object">http://nbn-resolving.org/urn:nbn:de:101:1-2018092707551425199092</mods:url></mods:location><mods:language><mods:languageTerm authority="iso639-2b" type="code">ger</mods:languageTerm></mods:language><mods:originInfo eventType="digitization"><mods:place><mods:placeTerm type="text">Leipzig</mods:placeTerm></mods:place><mods:place><mods:placeTerm type="text">Frankfurt am Main</mods:placeTerm></mods:place><mods:publisher>Deutsche Nationalbibliothek</mods:publisher><mods:dateIssued encoding="iso8601" keyDate="yes">2018</mods:dateIssued></mods:originInfo><mods:physicalDescription><mods:extent>Bez. u.M.: PHOTOGRAVURE R. PAULUSSEN, Wien</mods:extent><mods:extent>1 Ex.</mods:extent><mods:digitalOrigin>reformatted digital</mods:digitalOrigin></mods:physicalDescription><mods:titleInfo><mods:title>Porträt Franz Kroh (Pseudonym Hans Blumenthal)</mods:title><mods:subTitle>Heliogravüre</mods:subTitle></mods:titleInfo></mods:mods></METS:xmlData></METS:mdWrap></METS:dmdSec><METS:amdSec ID="amd_1163022497"><METS:rightsMD ID="rights_1163022497"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVRIGHTS"><METS:xmlData><dv:rights><dv:owner>Deutsche Nationalbibliothek</dv:owner><dv:ownerContact>mailto:digitalisierung@dnb.de</dv:ownerContact><dv:ownerlogo>https://www.dnb.de/logo-dnb-dfg-viewer</dv:ownerlogo><dv:ownerSiteURL>https://www.dnb.de/</dv:ownerSiteURL><dv:license>http://rightsstatements.org/vocab/InC/1.0/</dv:license></dv:rights></METS:xmlData></METS:mdWrap></METS:rightsMD><METS:digiprovMD ID="digiprov_1163022497"><METS:mdWrap MDTYPE="OTHER" MIMETYPE="text/xml" OTHERMDTYPE="DVLINKS"><METS:xmlData><dv:links><dv:reference>https://d-nb.info/1163022497</dv:reference><dv:presentation>https://nbn-resolving.org/urn:nbn:de:101:1-2018092707551425199092</dv:presentation></dv:links></METS:xmlData></METS:mdWrap></METS:digiprovMD></METS:amdSec><METS:fileSec><METS:fileGrp USE="THUMBS"><METS:file ID="THUMBS_1163022497_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163022497/img/page/1/p.jpg?reduce=64.6"/></METS:file></METS:fileGrp><METS:fileGrp USE="DEFAULT"><METS:file ID="DEFAULT_1163022497_1"><METS:FLocat LOCTYPE="URL" xlink:href="https://portal.dnb.de/bookviewer/view/1163022497/img/page/1/p.jpg?reduce=6.9"/></METS:file></METS:fileGrp></METS:fileSec><METS:structMap TYPE="PHYSICAL"><METS:div ID="physMD_1163022497" TYPE="physSequence"><METS:div ID="physMD_1163022497_1" LABEL="1" ORDER="1" ORDERLABEL="1" TYPE="page"><METS:fptr FILEID="THUMBS_1163022497_1"/><METS:fptr FILEID="DEFAULT_1163022497_1"/></METS:div></METS:div></METS:structMap><METS:structMap TYPE="LOGICAL"><METS:div ADMID="amd_1163022497" DMDI ...

# %% [markdown]
# ## OAI- Schnittstelle <a class="anchor" id="API2"></a>

# %% [markdown]
# ## SRU- Schnittstelle <a class="anchor" id="API3"></a>
