# %%
from polymatheia.data.reader import OAIRecordReader

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=1)
for record in reader:
    print(record)
# Out:
# {
#   "header": {
#     "identifier": {
#       "_text": "oai:www.digizeitschriften.de:PPN598188037_0036|LOG_0004"
#     },
#     "datestamp": {
#       "_text": "2020-09-01T10:43:53Z"
#     },
#     "setSpec": {}
#   },
#   "metadata": {
#     "{http://www.openarchives.org/OAI/2.0/oai_dc/}dc": {
#       "_attrib": {
#         "xsi_schemaLocation": "http://www.openarchives.org/OAI/2.0/oai_dc/ http://www.openarchives.org/OAI/2.0/oai_dc.xsd"
#       },
#       "dc_title": {
#         "_text": "Issue 1 "
#       },
#       "dc_subject": [
#         {
#           "_text": "340.law"
#         },
#         {
#           "_text": "300.sociology"
#         },
#         {
#           "_text": "PeriodicalIssue"
#         }
#       ],
#       "dc_language": {
#         "_text": "ger"
#       },
#       "dc_type": {
#         "_text": "Text"
#       },
#       "dc_format": [
#         {
#           "_text": "image/jpeg"
#         },
#         {
#           "_text": "application/pdf"
#         }
#       ],
#       "dc_identifier": [
#         {
#           "_text": "http://resolver.sub.uni-goettingen.de/purl?PPN598188037_0036|LOG_0004"
#         },
#         {
#           "_text": "DigiZeit PPN598188037_0036|LOG_0004"
#         }
#       ],
#       "dc_source": {
#         "_text": ": Zeitschrift f\u00fcr Rechtssoziologie. 36 2016"
#       },
#       "dc_rights": [
#         {
#           "_text": "DeGruyter"
#         },
#         {
#           "_text": "Sociology"
#         },
#         {
#           "_text": "Law"
#         },
#         {
#           "_text": "DigiZeitschriften Abo"
#         }
#       ]
#     }
#   }
# }

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=1)
for record in reader:
    print(record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_subject)
# Out:
# [{'_text': '340.law'}, {'_text': '300.sociology'}, {'_text': 'PeriodicalIssue'}]

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=1)
for record in reader:
    print(record.metadata['{http://www.openarchives.org/OAI/2.0/oai_dc/}dc'].dc_subject)

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=1, metadata_prefix='mets')
for record in reader:
    print(record)
# Out:
# {
#   "header": {
#     "identifier": {
#       "_text": "oai:www.digizeitschriften.de:PPN598188037_0036"
#     },
#     "datestamp": {
#       "_text": "2020-09-01T10:43:53Z"
#     },
#     "setSpec": {}
#   },
#   "metadata": {
#     "{http://www.loc.gov/METS/}mets": {
#       "_attrib": {
#         "OBJID": "",
#         "xsi_schemaLocation": "http://www.loc.gov/standards/premis/ http://www.loc.gov/standards/premis/v2/premis-v2-0.xsd http://www.loc.gov/mods/v3 http://www.loc.gov/standards/mods/v3/mods-3-5.xsd http://www.loc.gov/METS/ http://www.loc.gov/standards/mets/mets.xsd http://www.loc.gov/standards/mix/ http://www.loc.gov/standards/mix/mix.xsd"
#       },
#       "mets_metsHdr": {
#         "_attrib": {
#           "CREATEDATE": "2020-09-01T10:37:44Z"
#         },
#         "mets_agent": {
#           "_attrib": {
#             "OTHERTYPE": "SOFTWARE",
#             "ROLE": "CREATOR",
#             "TYPE": "OTHER"
#           },
#           "mets_name": {
#             "_text": "Goobi - ugh-3.0-ugh-2.0.0-29-g3b6efe1 - 21\u2212December\u22122016"
#           },
#           "mets_note": {
#             "_text": "Goobi"
#           }
#         }
#       },
#       "mets_dmdSec": [
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0001"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Zeitschrift f\u00fcr Rechtssoziologie"
#                   }
#                 },
#                 "mods_location": {
#                   "mods_physicalLocation": {
#                     "_text": "Heidelberg - ZSA 4528 B",
#                     "_attrib": {
#                       "type": "shelfmark"
#                     }
#                   }
#                 },
#                 "mods_originInfo": {
#                   "mods_place": {
#                     "mods_placeTerm": {
#                       "_text": "Berlin",
#                       "_attrib": {
#                         "type": "text"
#                       }
#                     }
#                   },
#                   "mods_dateIssued": {
#                     "_text": "2016",
#                     "_attrib": {
#                       "encoding": "w3cdtf",
#                       "keyDate": "yes"
#                     }
#                   },
#                   "mods_publisher": {
#                     "_text": "De Gruyter Oldenbourg"
#                   }
#                 },
#                 "mods_language": {
#                   "mods_languageTerm": {
#                     "_text": "ger",
#                     "_attrib": {
#                       "authority": "iso639-2b",
#                       "type": "code"
#                     }
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "_tail": "\n                  Bora, Alfons [u.a.]\n               ",
#                     "mods_roleTerm": {
#                       "_text": "oth",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   }
#                 },
#                 "mods_identifier": [
#                   {
#                     "_text": "PPN130441694_0036",
#                     "_attrib": {
#                       "type": "PPNanalog"
#                     }
#                   },
#                   {
#                     "_text": "PPN598188037_0036",
#                     "_attrib": {
#                       "type": "gbv-ppn"
#                     }
#                   },
#                   {
#                     "_text": "http://resolver.sub.uni-goettingen.de/purl?PPN598188037_0036",
#                     "_attrib": {
#                       "type": "purl"
#                     }
#                   }
#                 ],
#                 "mods_relatedItem": {
#                   "_attrib": {
#                     "type": "host"
#                   },
#                   "mods_recordInfo": {
#                     "mods_recordIdentifier": {
#                       "_text": "PPN598188037",
#                       "_attrib": {
#                         "source": "gbv-ppn"
#                       }
#                     }
#                   }
#                 },
#                 "mods_recordInfo": {
#                   "mods_recordIdentifier": {
#                     "_text": "PPN598188037_0036",
#                     "_attrib": {
#                       "source": "gbv-ppn"
#                     }
#                   }
#                 },
#                 "mods_part": {
#                   "_attrib": {
#                     "order": "360",
#                     "type": "host"
#                   },
#                   "mods_detail": {
#                     "mods_number": {
#                       "_text": "36"
#                     }
#                   }
#                 },
#                 "mods_classification": [
#                   {
#                     "_text": "300 Sociology",
#                     "_attrib": {
#                       "authority": "dz"
#                     }
#                   },
#                   {
#                     "_text": "340 Law",
#                     "_attrib": {
#                       "authority": "dz"
#                     }
#                   }
#                 ],
#                 "mods_physicalDescription": {
#                   "mods_note": {
#                     "_text": "Antiqua",
#                     "_attrib": {
#                       "type": "script"
#                     }
#                   }
#                 },
#                 "mods_accessCondition": [
#                   {
#                     "_text": "Gesamtabo",
#                     "_attrib": {
#                       "type": "dz"
#                     }
#                   },
#                   {
#                     "_text": "DeGruyter",
#                     "_attrib": {
#                       "type": "dz"
#                     }
#                   },
#                   {
#                     "_text": "Sociology",
#                     "_attrib": {
#                       "type": "dz"
#                     }
#                   },
#                   {
#                     "_text": "Law",
#                     "_attrib": {
#                       "type": "dz"
#                     }
#                   }
#                 ]
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0002"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Issue 1"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0003"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Inhalt"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0004"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Editorial"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0005"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Soziologie der Mediation"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0006"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Vorbemerkungen zum Themenschwerpunkt"
#                   }
#                 },
#                 "mods_name": [
#                   {
#                     "_attrib": {
#                       "type": "personal"
#                     },
#                     "mods_role": {
#                       "mods_roleTerm": {
#                         "_text": "cre",
#                         "_attrib": {
#                           "authority": "marcrelator",
#                           "type": "code"
#                         }
#                       }
#                     },
#                     "mods_namePart": [
#                       {
#                         "_text": "Heck",
#                         "_attrib": {
#                           "type": "family"
#                         }
#                       },
#                       {
#                         "_text": "Justus",
#                         "_attrib": {
#                           "type": "given"
#                         }
#                       }
#                     ],
#                     "mods_displayForm": {
#                       "_text": "Heck, Justus"
#                     }
#                   },
#                   {
#                     "_attrib": {
#                       "type": "personal"
#                     },
#                     "mods_role": {
#                       "mods_roleTerm": {
#                         "_text": "cre",
#                         "_attrib": {
#                           "authority": "marcrelator",
#                           "type": "code"
#                         }
#                       }
#                     },
#                     "mods_namePart": [
#                       {
#                         "_text": "Bora",
#                         "_attrib": {
#                           "type": "family"
#                         }
#                       },
#                       {
#                         "_text": "Alfons",
#                         "_attrib": {
#                           "type": "given"
#                         }
#                       }
#                     ],
#                     "mods_displayForm": {
#                       "_text": "Bora, Alfons"
#                     }
#                   },
#                   {
#                     "_attrib": {
#                       "type": "personal"
#                     },
#                     "mods_role": {
#                       "mods_roleTerm": {
#                         "_text": "cre",
#                         "_attrib": {
#                           "authority": "marcrelator",
#                           "type": "code"
#                         }
#                       }
#                     },
#                     "mods_namePart": [
#                       {
#                         "_text": "Jost",
#                         "_attrib": {
#                           "type": "family"
#                         }
#                       },
#                       {
#                         "_text": "Fritz",
#                         "_attrib": {
#                           "type": "given"
#                         }
#                       }
#                     ],
#                     "mods_displayForm": {
#                       "_text": "Jost, Fritz"
#                     }
#                   }
#                 ]
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0007"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Die Professionalisierung(en) der Mediation"
#                   },
#                   "mods_subTitle": {
#                     "_text": "the professionalisation(s) of mediation"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Maiwald",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Kai-Olaf",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Maiwald, Kai-Olaf"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0008"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Professionalisierungsbed\u00fcrftige Vermittlungspraxis oder Sozialtechnologie?"
#                   },
#                   "mods_subTitle": {
#                     "_text": "Mediation practice in need of professionalisation or social engineering?"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "M\u00fcnte",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Peter",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "M\u00fcnte, Peter"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0009"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Der beteiligte Unbeteiligte. Wie vermittelnde Dritte Konflikte transformieren"
#                   },
#                   "mods_subTitle": {
#                     "_text": "the involved uninvolved. How mediating third parties transform conflicts"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Heck",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Justus",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Heck, Justus"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0010"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Unrecht und Rechtfertigung"
#                   },
#                   "mods_subTitle": {
#                     "_text": "Injustice and justification"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Messmer",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Heinz",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Messmer, Heinz"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0011"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Vom Richten zum Schlichten - juristische Entscheidungssysteme im Umbruch"
#                   },
#                   "mods_subTitle": {
#                     "_text": "from judging to conciliation - juridical decision-making systems in transition"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Collin",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Peter",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Collin, Peter"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0012"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Soziologie der Mediation aus historischer Perspektive"
#                   },
#                   "mods_subTitle": {
#                     "_text": "the sociology of mediation from a historical persprective"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Kamp",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Hermann",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Kamp, Hermann"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0013"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Abhandlung"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0014"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Zu H\u00e4ufigkeit und Determinanten rechtlicher Betreuung - Eine vergleichende Analyse von Daten aus Deutschland, \u00d6sterreich und der Schweiz"
#                   },
#                   "mods_subTitle": {
#                     "_text": "on the frequency and determinants of legal guardianship - a comparative analysis of data from Germany, Austria and Switzerland"
#                   }
#                 },
#                 "mods_name": [
#                   {
#                     "_attrib": {
#                       "type": "personal"
#                     },
#                     "mods_role": {
#                       "mods_roleTerm": {
#                         "_text": "cre",
#                         "_attrib": {
#                           "authority": "marcrelator",
#                           "type": "code"
#                         }
#                       }
#                     },
#                     "mods_namePart": [
#                       {
#                         "_text": "Estermann",
#                         "_attrib": {
#                           "type": "family"
#                         }
#                       },
#                       {
#                         "_text": "Josef",
#                         "_attrib": {
#                           "type": "given"
#                         }
#                       }
#                     ],
#                     "mods_displayForm": {
#                       "_text": "Estermann, Josef"
#                     }
#                   },
#                   {
#                     "_attrib": {
#                       "type": "personal"
#                     },
#                     "mods_role": {
#                       "mods_roleTerm": {
#                         "_text": "cre",
#                         "_attrib": {
#                           "authority": "marcrelator",
#                           "type": "code"
#                         }
#                       }
#                     },
#                     "mods_namePart": [
#                       {
#                         "_text": "Fuchs",
#                         "_attrib": {
#                           "type": "family"
#                         }
#                       },
#                       {
#                         "_text": "Walter",
#                         "_attrib": {
#                           "type": "given"
#                         }
#                       }
#                     ],
#                     "mods_displayForm": {
#                       "_text": "Fuchs, Walter"
#                     }
#                   }
#                 ]
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0015"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Rezensionen"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0016"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Nachrufe"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0017"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Nachruf auf Andr\u00e9-Jean Arnaud (1936 - 2015)"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Guibentif",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Pierre",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Guibentif, Pierre"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0018"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Nachruf auf Theo Rasehorn (1918 - 2016)"
#                   }
#                 },
#                 "mods_name": [
#                   {
#                     "_attrib": {
#                       "type": "personal"
#                     },
#                     "mods_role": {
#                       "mods_roleTerm": {
#                         "_text": "cre",
#                         "_attrib": {
#                           "authority": "marcrelator",
#                           "type": "code"
#                         }
#                       }
#                     },
#                     "mods_namePart": [
#                       {
#                         "_text": "Blankenburg",
#                         "_attrib": {
#                           "type": "family"
#                         }
#                       },
#                       {
#                         "_text": "Erhard",
#                         "_attrib": {
#                           "type": "given"
#                         }
#                       }
#                     ],
#                     "mods_displayForm": {
#                       "_text": "Blankenburg, Erhard"
#                     }
#                   },
#                   {
#                     "_attrib": {
#                       "type": "personal"
#                     },
#                     "mods_role": {
#                       "mods_roleTerm": {
#                         "_text": "cre",
#                         "_attrib": {
#                           "authority": "marcrelator",
#                           "type": "code"
#                         }
#                       }
#                     },
#                     "mods_namePart": [
#                       {
#                         "_text": "Bora",
#                         "_attrib": {
#                           "type": "family"
#                         }
#                       },
#                       {
#                         "_text": "Alfons",
#                         "_attrib": {
#                           "type": "given"
#                         }
#                       }
#                     ],
#                     "mods_displayForm": {
#                       "_text": "Bora, Alfons"
#                     }
#                   }
#                 ]
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0019"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Autoren Rezensionen und der Nachrufe"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0020"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Richtlinien f\u00fcr Autorinnen und Autoren"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0021"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Issue 2"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0022"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Inhalt"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0023"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Die Versprechungen des Rechts. Dritter Kongress der deutschsprachigen Rechtssoziologie-Vereinigungen, 9. - 11. September 2015, Humboldt-Universit\u00e4t zu Berlin"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0024"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Recht als Praxis. Herausforderungen der Rechtsforschung heute"
#                   },
#                   "mods_subTitle": {
#                     "_text": "Law as practice. Challenges to law and society research today"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Baer",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Susanne",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Baer, Susanne"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0025"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Die Versprechungen der Wissenschaft. Forschung zu Recht und Gesellschaft im Kontext aktueller wissenschaftspolitischer Entwicklungen"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0026"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Einleitung"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Cottier",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Michelle",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Cottier, Michelle"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0027"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Reflexive Rechtssoziologie zwischen Wissenschaft und Zivilgesellschaft"
#                   },
#                   "mods_subTitle": {
#                     "_text": "reflexive sociology of law between science and civil society"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Guibentif",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Pierre",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Guibentif, Pierre"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0028"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Die transdisziplin\u00e4re Rechtsforschung braucht die Rechtssoziologie - und umgekehrt"
#                   },
#                   "mods_subTitle": {
#                     "_text": "transdisciplinary research on law and society - in need of the sociology of law (and vice versa)"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Kocher",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Eva",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Kocher, Eva"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0029"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Rechtssoziologie f\u00fcr Nachwuchsforschende - eine Versprechung?"
#                   },
#                   "mods_subTitle": {
#                     "_text": "Sociology of law for young academics - a promise?"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Fuchs",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Walter",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Fuchs, Walter"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0030"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Responsive Rechtssoziologie"
#                   },
#                   "mods_subTitle": {
#                     "_text": "Responsive sociology of law"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Bora",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Alfons",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Bora, Alfons"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0031"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Abhandlung"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0032"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Understanding the German mixed tribunal"
#                   },
#                   "mods_subTitle": {
#                     "_text": "Gemischte Spruchk\u00f6rper in Deutschland"
#                   }
#                 },
#                 "mods_language": {
#                   "mods_languageTerm": {
#                     "_text": "eng",
#                     "_attrib": {
#                       "authority": "iso639-2b",
#                       "type": "code"
#                     }
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Machura",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Stefan",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Machura, Stefan"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0033"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Dokumentation"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0034"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Zur Zusammenarbeit von Rechtssoziologen und Justizpraktikern. In Erinnerung an Wolfgang Kaupen"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Rasehorn",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Theo",
#                       "_attrib": {
#                         "type": "given"
#                       }
#                     }
#                   ],
#                   "mods_displayForm": {
#                     "_text": "Rasehorn, Theo"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0035"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Nachruf"
#                   }
#                 }
#               }
#             }
#           }
#         },
#         {
#           "_attrib": {
#             "ID": "DMDLOG_0036"
#           },
#           "mets_mdWrap": {
#             "_attrib": {
#               "MDTYPE": "MODS"
#             },
#             "mets_xmlData": {
#               "mods_mods": {
#                 "mods_titleInfo": {
#                   "mods_title": {
#                     "_text": "Nachruf auf Jutta Limbach (1934 - 2016)"
#                   }
#                 },
#                 "mods_name": {
#                   "_attrib": {
#                     "type": "personal"
#                   },
#                   "mods_role": {
#                     "mods_roleTerm": {
#                       "_text": "cre",
#                       "_attrib": {
#                         "authority": "marcrelator",
#                         "type": "code"
#                       }
#                     }
#                   },
#                   "mods_namePart": [
#                     {
#                       "_text": "Plett",
#                       "_attrib": {
#                         "type": "family"
#                       }
#                     },
#                     {
#                       "_text": "Konstanze",
#                       "_attrib": {
# ...
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0299",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0300",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0301",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0302",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0303",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0304",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0305",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0306",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0307",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0308",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0309",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0310",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0311",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0312",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0313",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0314",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0315",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0316",
#               "xlink_from": "LOG_0040"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0287",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0288",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0289",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0290",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0291",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0292",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0293",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0294",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0295",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0296",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0297",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0298",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0299",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0300",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0301",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0302",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0303",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0304",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0305",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0306",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0307",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0308",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0309",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0310",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0311",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0312",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0313",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0314",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0315",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0316",
#               "xlink_from": "LOG_0041"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0317",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0318",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0319",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0320",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0321",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0322",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0323",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0324",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0325",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0326",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0327",
#               "xlink_from": "LOG_0042"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0317",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0318",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0319",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0320",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0321",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0322",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0323",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0324",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0325",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0326",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0327",
#               "xlink_from": "LOG_0043"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0328",
#               "xlink_from": "LOG_0044"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0329",
#               "xlink_from": "LOG_0044"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0330",
#               "xlink_from": "LOG_0044"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0331",
#               "xlink_from": "LOG_0044"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0332",
#               "xlink_from": "LOG_0044"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0333",
#               "xlink_from": "LOG_0044"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0334",
#               "xlink_from": "LOG_0044"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0328",
#               "xlink_from": "LOG_0045"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0329",
#               "xlink_from": "LOG_0045"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0330",
#               "xlink_from": "LOG_0045"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0331",
#               "xlink_from": "LOG_0045"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0332",
#               "xlink_from": "LOG_0045"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0333",
#               "xlink_from": "LOG_0045"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0334",
#               "xlink_from": "LOG_0045"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0335",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0336",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0337",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0338",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0339",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0340",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0341",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0342",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0343",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0344",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0345",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0346",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0347",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0348",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0349",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0350",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0351",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0352",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0353",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0354",
#               "xlink_from": "LOG_0046"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0355",
#               "xlink_from": "LOG_0047"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0356",
#               "xlink_from": "LOG_0048"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0357",
#               "xlink_from": "LOG_0048"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0358",
#               "xlink_from": "LOG_0048"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0359",
#               "xlink_from": "LOG_0048"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0360",
#               "xlink_from": "LOG_0048"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0361",
#               "xlink_from": "LOG_0048"
#             }
#           },
#           {
#             "_attrib": {
#               "xlink_to": "PHYS_0362",
#               "xlink_from": "LOG_0049"
#             }
#           }
#         ]
#       }
#     }
#   }
# }

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=1, metadata_prefix='mets')
for record in reader:
    print(record.metadata['{http://www.loc.gov/METS/}mets'].mets_dmdSec)
# Out:
# [{'_attrib': {'ID': 'DMDLOG_0001'}, 'mets_mdWrap': {'_attrib': {'MDTYPE': 'MODS'}, 'mets_xmlData': {'mods_mods': {'mods_titleInfo': {'mods_title': {'_text': 'Zeitschrift für Rechtssoziologie'}}, 'mods_location': {'mods_physicalLocation': {'_text': 'Heidelberg - ZSA 4528 B', '_attrib': {'type': 'shelfmark'}}}, 'mods_originInfo': {'mods_place': {'mods_placeTerm': {'_text': 'Berlin', '_attrib': {'type': 'text'}}}, 'mods_dateIssued': {'_text': '2016', '_attrib': {'encoding': 'w3cdtf', 'keyDate': 'yes'}}, 'mods_publisher': {'_text': 'De Gruyter Oldenbourg'}}, 'mods_language': {'mods_languageTerm': {'_text': 'ger', '_attrib': {'authority': 'iso639-2b', 'type': 'code'}}}, 'mods_name': {'_attrib': {'type': 'personal'}, 'mods_role': {'_tail': '\n                  Bora, Alfons [u.a.]\n               ', 'mods_roleTerm': {'_text': 'oth', '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}}, 'mods_identifier': [{'_text': 'PPN130441694_0036', '_attrib': {'type': 'PPNanalog'}}, {'_text': 'PPN598188037_0036', '_attrib': {'type': 'gbv-ppn'}}, {'_text': 'http://resolver.sub.uni-goettingen.de/purl?PPN598188037_0036', '_attrib': {'type': 'purl'}}], 'mods_relatedItem': {'_attrib': {'type': 'host'}, 'mods_recordInfo': {'mods_recordIdentifier': {'_text': 'PPN598188037', '_attrib': {'source': 'gbv-ppn'}}}}, 'mods_recordInfo': {'mods_recordIdentifier': {'_text': 'PPN598188037_0036', '_attrib': {'source': 'gbv-ppn'}}}, 'mods_part': {'_attrib': {'order': '360', 'type': 'host'}, 'mods_detail': {'mods_number': {'_text': '36'}}}, 'mods_classification': [{'_text': '300 Sociology', '_attrib': {'authority': 'dz'}}, {'_text': '340 Law', '_attrib': {'authority': 'dz'}}], 'mods_physicalDescription': {'mods_note': {'_text': 'Antiqua', '_attrib': {'type': 'script'}}}, 'mods_accessCondition': [{'_text': 'Gesamtabo', '_attrib': {'type': 'dz'}}, {'_text': 'DeGruyter', '_attrib': {'type': 'dz'}}, {'_text': 'Sociology', '_attrib': {'type': 'dz'}}, {'_text': 'Law', '_attrib': {'type': 'dz'}}]}}}}, {'_attrib': {'ID': 'DMDLOG_0002'}, 'mets_mdWrap': {'_attrib': {'MDTYPE': 'MODS'}, 'mets_xmlData': {'mods_mods': {'mods_titleInfo': {'mods_title': {'_text': 'Issue 1'}}}}}}, {'_attrib': {'ID': 'DMDLOG_0003'}, 'mets_mdWrap': {'_attrib': {'MDTYPE': 'MODS'}, 'mets_xmlData': {'mods_mods': {'mods_titleInfo': {'mods_title': {'_text': 'Inhalt'}}}}}}, {'_attrib': {'ID': 'DMDLOG_0004'}, 'mets_mdWrap': {'_attrib': {'MDTYPE': 'MODS'}, 'mets_xmlData': {'mods_mods': {'mods_titleInfo': {'mods_title': {'_text': 'Editorial'}}}}}}, {'_attrib': {'ID': 'DMDLOG_0005'}, 'mets_mdWrap': {'_attrib': {'MDTYPE': 'MODS'}, 'mets_xmlData': {'mods_mods': {'mods_titleInfo': {'mods_title': {'_text': 'Soziologie der Mediation'}}}}}}, {'_attrib': {'ID': 'DMDLOG_0006'}, 'mets_mdWrap': {'_attrib': {'MDTYPE': 'MODS'}, 'mets_xmlData': {'mods_mods': {'mods_titleInfo': {'mods_title': {'_text': 'Vorbemerkungen zum Themenschwerpunkt'}}, 'mods_name': [{'_attrib': {'type': 'personal'}, 'mods_role': {'mods_roleTerm': {'_text': 'cre', '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}, 'mods_namePart': [{'_text': 'Heck', '_attrib': {'type': 'family'}}, {'_text': 'Justus', '_attrib': {'type': 'given'}}], 'mods_displayForm': {'_text': 'Heck, Justus'}}, {'_attrib': {'type': 'personal'}, 'mods_role': {'mods_roleTerm': {'_text': 'cre', '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}, 'mods_namePart': [{'_text': 'Bora', '_attrib': {'type': 'family'}}, {'_text': 'Alfons', '_attrib': {'type': 'given'}}], 'mods_displayForm': {'_text': 'Bora, Alfons'}}, {'_attrib': {'type': 'personal'}, 'mods_role': {'mods_roleTerm': {'_text': 'cre', '_attrib': {'authority': 'marcrelator', 'type': 'code'}}}, 'mods_namePart': [{'_text': 'Jost', '_attrib': {'type': 'family'}}, {'_text': 'Fritz', '_attrib': {'type': 'given'}}], 'mods_displayForm': {'_text': 'Jost, Fritz'}}]}}}}, {'_attrib': {'ID': 'DMDLOG_0007'}, 'mets_mdWrap': {'_attrib': {'MDTYPE': 'MODS'}, 'mets_xmlData': {'mods_mods': {'mods_titleInfo': {'mods_title': {'_text ...

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=1, metadata_prefix='mets')
for record in reader:
    print(record.metadata['{http://www.loc.gov/METS/}mets'].mets_dmdSec[0])
# Out:
# {
#   "_attrib": {
#     "ID": "DMDLOG_0001"
#   },
#   "mets_mdWrap": {
#     "_attrib": {
#       "MDTYPE": "MODS"
#     },
#     "mets_xmlData": {
#       "mods_mods": {
#         "mods_titleInfo": {
#           "mods_title": {
#             "_text": "Zeitschrift f\u00fcr Rechtssoziologie"
#           }
#         },
#         "mods_location": {
#           "mods_physicalLocation": {
#             "_text": "Heidelberg - ZSA 4528 B",
#             "_attrib": {
#               "type": "shelfmark"
#             }
#           }
#         },
#         "mods_originInfo": {
#           "mods_place": {
#             "mods_placeTerm": {
#               "_text": "Berlin",
#               "_attrib": {
#                 "type": "text"
#               }
#             }
#           },
#           "mods_dateIssued": {
#             "_text": "2016",
#             "_attrib": {
#               "encoding": "w3cdtf",
#               "keyDate": "yes"
#             }
#           },
#           "mods_publisher": {
#             "_text": "De Gruyter Oldenbourg"
#           }
#         },
#         "mods_language": {
#           "mods_languageTerm": {
#             "_text": "ger",
#             "_attrib": {
#               "authority": "iso639-2b",
#               "type": "code"
#             }
#           }
#         },
#         "mods_name": {
#           "_attrib": {
#             "type": "personal"
#           },
#           "mods_role": {
#             "_tail": "\n                  Bora, Alfons [u.a.]\n               ",
#             "mods_roleTerm": {
#               "_text": "oth",
#               "_attrib": {
#                 "authority": "marcrelator",
#                 "type": "code"
#               }
#             }
#           }
#         },
#         "mods_identifier": [
#           {
#             "_text": "PPN130441694_0036",
#             "_attrib": {
#               "type": "PPNanalog"
#             }
#           },
#           {
#             "_text": "PPN598188037_0036",
#             "_attrib": {
#               "type": "gbv-ppn"
#             }
#           },
#           {
#             "_text": "http://resolver.sub.uni-goettingen.de/purl?PPN598188037_0036",
#             "_attrib": {
#               "type": "purl"
#             }
#           }
#         ],
#         "mods_relatedItem": {
#           "_attrib": {
#             "type": "host"
#           },
#           "mods_recordInfo": {
#             "mods_recordIdentifier": {
#               "_text": "PPN598188037",
#               "_attrib": {
#                 "source": "gbv-ppn"
#               }
#             }
#           }
#         },
#         "mods_recordInfo": {
#           "mods_recordIdentifier": {
#             "_text": "PPN598188037_0036",
#             "_attrib": {
#               "source": "gbv-ppn"
#             }
#           }
#         },
#         "mods_part": {
#           "_attrib": {
#             "order": "360",
#             "type": "host"
#           },
#           "mods_detail": {
#             "mods_number": {
#               "_text": "36"
#             }
#           }
#         },
#         "mods_classification": [
#           {
#             "_text": "300 Sociology",
#             "_attrib": {
#               "authority": "dz"
#             }
#           },
#           {
#             "_text": "340 Law",
#             "_attrib": {
#               "authority": "dz"
#             }
#           }
#         ],
#         "mods_physicalDescription": {
#           "mods_note": {
#             "_text": "Antiqua",
#             "_attrib": {
#               "type": "script"
#             }
#           }
#         },
#         "mods_accessCondition": [
#           {
#             "_text": "Gesamtabo",
#             "_attrib": {
#               "type": "dz"
#             }
#           },
#           {
#             "_text": "DeGruyter",
#             "_attrib": {
#               "type": "dz"
#             }
#           },
#           {
#             "_text": "Sociology",
#             "_attrib": {
#               "type": "dz"
#             }
#           },
#           {
#             "_text": "Law",
#             "_attrib": {
#               "type": "dz"
#             }
#           }
#         ]
#       }
#     }
#   }
# }

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=1, metadata_prefix='mets')
for record in reader:
    print(record.metadata['{http://www.loc.gov/METS/}mets'].mets_dmdSec[0].mets_mdWrap.mets_xmlData.mods_mods.mods_titleInfo.mods_title._text)
# Out:
# Zeitschrift für Rechtssoziologie

# %%
reader = OAIRecordReader('http://www.digizeitschriften.de/oai2/', max_records=10, metadata_prefix='mets')
for record in reader:
    print(record.metadata['{http://www.loc.gov/METS/}mets'].mets_dmdSec[0].mets_mdWrap.mets_xmlData.mods_mods.mods_titleInfo.mods_title._text)
# Out:
# Zeitschrift für Rechtssoziologie
# Review of world economics
# Sozialer Sinn
# Jahrbücher für Nationalökonomie und Statistik
# Zeitschrift für Wirtschaftspolitik
# Historisches Jahrbuch
# Zeitschrift für deutsches Altertum und deutsche Literatur
# Zeitschrift für französische Sprache und Literatur
# Vierteljahrschrift für Sozial- und Wirtschaftsgeschichte
# L' Homme
